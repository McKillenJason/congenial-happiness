# %%
print("Hello, Thason!")
print("Adding to check changes go through."))
# Out:
# Hello, Thason!

# %%
import pandas as pd
import sklearn
import numpy as np

# Libraries for data visualisation
import matplotlib.pyplot as plt

# load dataset
housing = pd.read_csv('housing.csv')

# Drops the seller ID column, which is not necessary for our analysis
housing = housing.drop(['sellerId'], axis=1)

housing.head()
# Out:
#         id                                              title featuredLevel  \
# 0  3626025  11 Chestnut Crescent, Bridgemount, Carrigaline...      featured
# 1  3675175  58 The Glen, Kilnacourt Woods, Portarlington, ...      featured
# 2  3673450        16 Dodderbrook Park, Ballycullen, Dublin 24      featured
# 3  3649708      31 Lissanalta Drive, Dooradoyle, Co. Limerick      featured
# 4  3643947                5 Columba Terrace, Kells, Co. Meath      featured
#
#   publishDate   price  numBedrooms  numBathrooms    propertyType  \
# 0  2022-01-28  290000            3             3  End of Terrace
# 1  2022-01-28  225000            3             2          Semi-D
# 2  2022-01-27  575000            4             3          Semi-D
# 3  2022-01-28  299000            3             3          Semi-D
# 4  2022-01-28  120000            3             1         Terrace
#
#    propertySize category  ...       seller_name              seller_branch  \
# 0          96.0      Buy  ...       Roy Dennehy        Dennehy Auctioneers
# 1          93.0      Buy  ...     Marie Kiernan  Tom McDonald & Associates
# 2         162.0      Buy  ...          Moovingo                   Moovingo
# 3           NaN      Buy  ...  DNG Cusack Dunne           DNG Cusack Dunne
# 4          68.0      Buy  ...   REA T&J Gavigan          REA T & J Gavigan
#
#       sellerType m_totalImages  m_hasVideo  m_hasVirtualTour  m_hasBrochure  \
# 0  BRANDED_AGENT          16.0       False             False          False
# 1  BRANDED_AGENT          33.0       False             False          False
# 2  BRANDED_AGENT          38.0       False              True          False
# 3  BRANDED_AGENT          22.0       False             False          False
# 4  BRANDED_AGENT           5.0       False             False          False
#
#    ber_rating longitude   latitude
# 0          C2 -8.382500  51.822940
# 1          C1 -7.177098  53.157465
# 2          A3 -6.342763  53.269493
# 3          C2 -8.640716  52.629588
# 4           G -6.879797  53.728601
#
# [5 rows x 21 columns]

# %%
# Instantiates max and min values for attributes
max_bedrooms = 8
min_bedrooms = 1

max_bathrooms = 8
min_bathrooms = 1

max_longitude = 0
min_longitude = -30

max_latitude = 56
min_latitude = 39

max_price = 1000000
min_price = 50000

max_propertySize = 500
min_propertySize = 100

# %%
housing.describe()
# Out:
#                  id           price  numBedrooms  numBathrooms  propertySize  \
# count  2.186000e+03     2186.000000  2186.000000   2186.000000   1837.000000
# mean   3.623398e+06   342755.237877     3.491766      2.341720    156.381600
# std    2.752431e+05   189287.456689     1.008057      1.035245     91.516703
# min    1.092100e+04    20000.000000     1.000000      1.000000    100.000000
# 25%    3.653256e+06   209962.500000     3.000000      2.000000    113.000000
# 50%    3.673156e+06   295000.000000     3.000000      2.000000    130.000000
# 75%    3.685842e+06   425000.000000     4.000000      3.000000    168.000000
# max    3.695402e+06  1000000.000000     8.000000      8.000000   1350.000000
#
#          AMV_price  m_totalImages    longitude     latitude
# count  2186.000000    2186.000000  2186.000000  2186.000000
# mean      0.053065      19.234218    -7.419114    53.131204
# std       0.224214      11.236588     1.146567     0.695450
# min       0.000000       0.000000   -10.377464    51.491520
# 25%       0.000000      12.000000    -8.456857    52.656822
# 50%       0.000000      17.000000    -7.175259    53.295901
# 75%       0.000000      24.000000    -6.319126    53.447794
# max       1.000000     104.000000    -6.028016    55.278942

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2186 entries, 2 to 3966
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2186 non-null   int64
#  1   title             2186 non-null   object
#  2   featuredLevel     2186 non-null   object
#  3   publishDate       2186 non-null   object
#  4   price             2186 non-null   int64
#  5   numBedrooms       2186 non-null   int64
#  6   numBathrooms      2186 non-null   int64
#  7   propertyType      2186 non-null   object
#  8   propertySize      1837 non-null   float64
#  9   category          2186 non-null   object
#  10  AMV_price         2186 non-null   int64
#  11  seller_name       2186 non-null   object
#  12  seller_branch     2186 non-null   object
#  13  sellerType        2186 non-null   object
#  14  m_totalImages     2186 non-null   float64
#  15  m_hasVideo        2186 non-null   bool
#  16  m_hasVirtualTour  2186 non-null   bool
#  17  m_hasBrochure     2186 non-null   bool
#  18  ber_rating        2186 non-null   object
#  19  longitude         2186 non-null   float64
#  20  latitude          2186 non-null   float64
# dtypes: bool(3), float64(4), int64(5), object(9)
# memory usage: 330.9+ KB

# %%
# Removes all houses where the value is greater than the maximum price threshold
housing.drop(housing[housing.price > max_price].index, inplace=True)

# %%
# Removes all houses above the specified max number of bathrooms threshold
housing.drop(housing[housing.numBathrooms > max_bathrooms].index, inplace=True)

# %%
# Removes all houses above the specified max number of bedrooms threshold
housing.drop(housing[housing.numBedrooms > max_bedrooms].index, inplace=True)

# %%
# Removes all houses outside the specified longitude range
housing.drop(housing[(housing.longitude > max_longitude) | (housing.longitude < min_longitude)].index, inplace=True)

# %%
# Removes all houses outside the specified latitude range
housing.drop(housing[(housing.latitude > max_latitude) | (housing.latitude < min_latitude)].index, inplace=True)

# %%
# Removes all houses outside the specified latitude range
housing.drop(housing[(housing.propertySize > max_propertySize) | (housing.propertySize < min_propertySize)].index, inplace=True)

# %%
housing.dropna(subset=["numBedrooms"])
housing.dropna(subset=["numBathrooms"])
housing.dropna(subset=["propertySize"])
# Out:
#            id                                              title  \
# 2     3673450        16 Dodderbrook Park, Ballycullen, Dublin 24
# 5     3598816  75 The Lawn, Coolroe Meadows, Ballincollig, Co...
# 7     3642653     11 Douglas Wells, Well Road, Douglas, Co. Cork
# 8     3673958          40 Glenard Crescent, Salthill, Co. Galway
# 9     3486462                         Ballykeeran, Co. Westmeath
# ...       ...                                                ...
# 3959  3644638  Curragh Wood Kilanerin Gorey, Kilanerin, Co. W...
# 3961  3644422            8 Sliabh Cairbe, Drumlish, Co. Longford
# 3962  3644416              13 Cherry Close, Bellfield, Waterford
# 3965  3644099              School Land, Ballinalee, Co. Longford
# 3966  3603137  14 Coolmagort Ave, Beaufort, Killarney, Co. Kerry
#
#      featuredLevel publishDate   price  numBedrooms  numBathrooms  \
# 2         featured  2022-01-27  575000            4             3
# 5         featured  2022-01-30  400000            4             3
# 7         featured  2022-01-30  490000            2             2
# 8         featured  2022-01-30  680000            5             3
# 9         featured  2022-01-30  695000            7             6
# ...            ...         ...     ...          ...           ...
# 3959      standard  2022-01-12  429000            3             2
# 3961      standard  2021-12-13  185000            4             3
# 3962      standard  2022-01-24  235000            3             3
# 3965      standard  2021-12-04  170000            4             2
# 3966      standard  2022-01-30  250000            3             2
#
#      propertyType  propertySize category  ...         seller_name  \
# 2          Semi-D         162.0      Buy  ...            Moovingo
# 5          Semi-D         113.0      Buy  ...         Norma Healy
# 7       Apartment         104.0      Buy  ...      Stuart O'Grady
# 8          Semi-D         169.0      Buy  ...       Tony Kavanagh
# 9        Detached         400.0      Buy  ...        Helena Kenny
# ...           ...           ...      ...  ...                 ...
# 3959     Bungalow         149.0      Buy  ...  Rooney Auctioneers
# 3961       Semi-D         125.0      Buy  ...         Paul O'Shea
# 3962       Semi-D         103.0      Buy  ...       Robert Forbes
# 3965     Detached         128.0      Buy  ...          Tom Hickey
# 3966     Bungalow         116.0      Buy  ...         Coonan Naas
#
#                            seller_branch       sellerType m_totalImages  \
# 2                               Moovingo    BRANDED_AGENT          38.0
# 5                 Sherry FitzGerald Cork    BRANDED_AGENT          20.0
# 7                 Sherry FitzGerald Cork    BRANDED_AGENT          16.0
# 8               Sherry FitzGerald Galway    BRANDED_AGENT          21.0
# 9              Sherry FitzGerald O'Meara    BRANDED_AGENT          24.0
# ...                                  ...              ...           ...
# 3959        Rooney Auctioneers -Limerick    BRANDED_AGENT          53.0
# 3961              Sherry FitzGerald Cork    BRANDED_AGENT          34.0
# 3962                     Forbes Property    BRANDED_AGENT          24.0
# 3965  Hickey O'Donoghue Auctioneers Ltd.    BRANDED_AGENT          38.0
# 3966            Coonan Estate Agents Ltd  UNBRANDED_AGENT          69.0
#
#       m_hasVideo  m_hasVirtualTour  m_hasBrochure  ber_rating longitude  \
# 2          False              True          False          A3 -6.342763
# 5           True             False          False          C1 -8.614786
# 7          False             False          False          B3 -8.436105
# 8          False             False          False          C2 -9.082283
# 9           True             False          False          C2 -7.899131
# ...          ...               ...            ...         ...       ...
# 3959        True             False          False          A2 -8.653520
# 3961       False             False          False          A3 -8.315556
# 3962       False              True          False          A1 -7.212145
# 3965       False              True          False          A2 -8.652927
# 3966       False              True          False          A3 -6.792938
#
#        latitude
# 2     53.269493
# 5     51.883612
# 7     51.879916
# 8     53.266491
# 9     53.446741
# ...         ...
# 3959  52.664386
# 3961  51.849705
# 3962  53.647194
# 3965  52.664558
# 3966  53.166008
#
# [1822 rows x 21 columns]

# %%
# %matplotlib inline
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %%
housing.plot(kind='scatter', x='longitude', y='latitude', c="price", cmap=plt.get_cmap('jet'), colorbar=True, figsize=(20, 15), s=10)
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['price'].sort_values(ascending=False)
# Out:
# price               1.000000
# numBathrooms        0.329302
# numBedrooms         0.314397
# propertySize        0.273491
# m_hasBrochure       0.005987
# longitude           0.004769
# m_hasVirtualTour   -0.007369
# latitude           -0.022780
# m_hasVideo         -0.025011
# m_totalImages      -0.067639
# id                 -0.095496
# AMV_price          -0.200548
# Name: price, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ['price', 'numBathrooms', 'numBedrooms', 'propertySize']
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='price', ylabel='price'>,
#         <AxesSubplot:xlabel='numBathrooms', ylabel='price'>,
#         <AxesSubplot:xlabel='numBedrooms', ylabel='price'>,
#         <AxesSubplot:xlabel='propertySize', ylabel='price'>],
#        [<AxesSubplot:xlabel='price', ylabel='numBathrooms'>,
#         <AxesSubplot:xlabel='numBathrooms', ylabel='numBathrooms'>,
#         <AxesSubplot:xlabel='numBedrooms', ylabel='numBathrooms'>,
#         <AxesSubplot:xlabel='propertySize', ylabel='numBathrooms'>],
#        [<AxesSubplot:xlabel='price', ylabel='numBedrooms'>,
#         <AxesSubplot:xlabel='numBathrooms', ylabel='numBedrooms'>,
#         <AxesSubplot:xlabel='numBedrooms', ylabel='numBedrooms'>,
#         <AxesSubplot:xlabel='propertySize', ylabel='numBedrooms'>],
#        [<AxesSubplot:xlabel='price', ylabel='propertySize'>,
#         <AxesSubplot:xlabel='numBathrooms', ylabel='propertySize'>,
#         <AxesSubplot:xlabel='numBedrooms', ylabel='propertySize'>,
#         <AxesSubplot:xlabel='propertySize', ylabel='propertySize'>]],
#       dtype=object)

# %%
# Separates the training dataset into the training labels and target labels
housing = train_set.drop("price", axis=1)
housing_labels = train_set["price"].copy()
